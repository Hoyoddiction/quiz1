# %%
import pandas as pd
df = pd.read_csv('wait.csv')
df.info
# Out:
# <bound method DataFrame.info of        Unnamed: 0               Name  Age  Gender Blood Type  \
# 0               0      Bobby JacksOn   30    Male         B-
# 1               1       LesLie TErRy   62    Male         A+
# 2               2        DaNnY sMitH   76  Female         A-
# 3               3       andrEw waTtS   28  Female         O+
# 4               4      adrIENNE bEll   43  Female        AB+
# ...           ...                ...  ...     ...        ...
# 55495       55495  eLIZABeTH jaCkSOn   42  Female         O+
# 55496       55496         KYle pEREz   61  Female        AB-
# 55497       55497       HEATher WaNG   38  Female         B+
# 55498       55498     JENniFER JOneS   43    Male         O-
# 55499       55499       jAMES GARCiA   53  Female         O+
#
#       Medical Condition Date of Admission            Doctor  \
# 0                Cancer        2024-01-31     Matthew Smith
# 1               Obesity        2019-08-20   Samantha Davies
# ...

# %%
df.isnull().sum()
df['Doctor'].fillna(df['Doctor'].mode()[0], inplace=True)
df.head()
# Out:
#    Unnamed: 0           Name  Age  Gender Blood Type Medical Condition  \
# 0           0  Bobby JacksOn   30    Male         B-            Cancer
# 1           1   LesLie TErRy   62    Male         A+           Obesity
# 2           2    DaNnY sMitH   76  Female         A-           Obesity
# 3           3   andrEw waTtS   28  Female         O+          Diabetes
# 4           4  adrIENNE bEll   43  Female        AB+            Cancer
#
#   Date of Admission            Doctor                    Hospital  \
# 0        2024-01-31     Matthew Smith             Sons and Miller
# 1        2019-08-20   Samantha Davies                     Kim Inc
# 2        2022-09-22  Tiffany Mitchell                    Cook PLC
# 3        2020-11-18       Kevin Wells  Hernandez Rogers and Vang,
# 4        2022-09-19    Kathleen Hanna                 White-White
#
#   Insurance Provider  Billing Amount  Room Number Admission Type  \
# 0         Blue Cross    18856.281306          328         Urgent
# ...

# %%
df.isnull().sum()
df['Medication'].fillna(df['Medication'].mode()[0], inplace=True)
df.info
# Out:
# <bound method DataFrame.info of        Unnamed: 0               Name  Age  Gender Blood Type  \
# 0               0      Bobby JacksOn   30    Male         B-
# 1               1       LesLie TErRy   62    Male         A+
# 2               2        DaNnY sMitH   76  Female         A-
# 3               3       andrEw waTtS   28  Female         O+
# 4               4      adrIENNE bEll   43  Female        AB+
# ...           ...                ...  ...     ...        ...
# 55495       55495  eLIZABeTH jaCkSOn   42  Female         O+
# 55496       55496         KYle pEREz   61  Female        AB-
# 55497       55497       HEATher WaNG   38  Female         B+
# 55498       55498     JENniFER JOneS   43    Male         O-
# 55499       55499       jAMES GARCiA   53  Female         O+
#
#       Medical Condition Date of Admission            Doctor  \
# 0                Cancer        2024-01-31     Matthew Smith
# 1               Obesity        2019-08-20   Samantha Davies
# ...

# %%
#fill done the most is ibuprofen change missing into ibuprofen most = ibuprofen

# %%
df["Age"].mean()
# Out:
# 51.53945945945946

# %%
df.isnull().sum()
df['Insurance Provider'].fillna(df['Insurance Provider'].mode()[0], inplace=True)
df.head()
# Out:
#    Unnamed: 0           Name  Age  Gender Blood Type Medical Condition  \
# 0           0  Bobby JacksOn   30    Male         B-            Cancer
# 1           1   LesLie TErRy   62    Male         A+           Obesity
# 2           2    DaNnY sMitH   76  Female         A-           Obesity
# 3           3   andrEw waTtS   28  Female         O+          Diabetes
# 4           4  adrIENNE bEll   43  Female        AB+            Cancer
#
#   Date of Admission            Doctor                    Hospital  \
# 0        2024-01-31     Matthew Smith             Sons and Miller
# 1        2019-08-20   Samantha Davies                     Kim Inc
# 2        2022-09-22  Tiffany Mitchell                    Cook PLC
# 3        2020-11-18       Kevin Wells  Hernandez Rogers and Vang,
# 4        2022-09-19    Kathleen Hanna                 White-White
#
#   Insurance Provider  Billing Amount  Room Number Admission Type  \
# 0         Blue Cross    18856.281306          328         Urgent
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0               0
# Name                     0
# Age                      0
# Gender                   0
# Blood Type               0
# Medical Condition        0
# Date of Admission        0
# Doctor                2198
# Hospital                 0
# Insurance Provider    2193
# Billing Amount           0
# Room Number              0
# Admission Type           0
# Discharge Date           0
# Medication            5417
# Test Results             0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import numpy as np
 
# Generate random data for the histogram
data = np.random.randn(1000)
 
# Plotting a basic histogram
plt.hist(data, bins=30, color='skyblue', edgecolor='black')
 
# Adding labels and title
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Basic Histogram')
 
# Display the plot
plt.show()

# %%
df = pd.DataFrame({'DateTime': []})

# %%
df.isnull().sum()
df['name'].fillna(df['name'].mode()[0], inplace=True)
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Alber\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 2
#       1 df.isnull().sum()
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np


np.random.seed(10)

data_1 = np.random.normal(30000, 1000, 200000)
data_2 = np.random.normal(20000, 1000, 200000)
data = [data_1,data_2]

fig = plt.figure(figsize =(10, 7))
ax = fig.add_axes([0, 0, 1, 1])




plt.show()
